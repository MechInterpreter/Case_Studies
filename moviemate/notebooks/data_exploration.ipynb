# %%
import pandas as pd
import matplotlib.pyplot as plt
from pipeline import Pipeline

# Initialize Pipeline
pipeline = Pipeline()

# Load Dataset
file_path = "/teamspace/studios/this_studio/u.data"
pipeline.load_dataset(file_path)

# Partition the data into training and testing sets
train_df, test_df = pipeline.partition_data(partition_type='temporal')
# Out:
# Dataset loaded with shape: (100000, 4)
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596
# Training set shape: (80000, 4)
# Testing set shape: (20000, 4)

# %%
# Visualize rating distributions
plt.figure(figsize=(10, 5))
pipeline.ratings_df['rating'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title('Ratings Distribution')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.grid(axis='y')
plt.show()

# Visualize timestamp distributions
plt.figure(figsize=(12, 6))
pipeline.ratings_df['timestamp'].plot(kind='hist', bins=50, color='coral')
plt.title('Timestamp Distribution')
plt.xlabel('Timestamp')
plt.ylabel('Frequency')
plt.show()

# %%
# Partitioning based on user-stratified sampling
temp_train_df, temp_test_df = pipeline.partition_data(partition_type='user_stratified')

print("User-Stratified Training Set: ")
print(temp_train_df.head())
print("User-Stratified Testing Set: ")
print(temp_test_df.head())
# Out:
# Training set shape: (82929, 4)
# Testing set shape: (17071, 4)
# User-Stratified Training Set:
#        user_id  item_id  rating  timestamp
# 214        259      255       4  874724710
# 83965      259      286       4  874724727
# 43027      259      298       4  874724754
# 21396      259      185       4  874724781
# 82655      259      173       4  874724843
# User-Stratified Testing Set:
#        user_id  item_id  rating  timestamp
# 4027       297      300       3  874953892
# 27797      297      258       5  874953892
# 18211      297      326       2  874953892
# 2785       297      286       5  874953892
# 79157      297      294       3  874953948
